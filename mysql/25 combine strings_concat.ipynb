# %%
from IPython.display import  Image
Image("/home/bruceashbee/Pictures/文字を連結する仕方.png")

# %% [markdown]
# # concat
# ##### CONTACT("STRING","STRING2","STAING3")

# %%
import mysql.connector as sql
import pandas as pd

mydb = sql.connect (
    host = "localhost",
    user = "root",
    password = "ZAQs8271911c$",
    auth_plugin='mysql_native_password',
    buffered = True,        
    database = "sql_fr_ai"
)



# change it to  no decimal place
mysql_query ="""
SELECT 
        CONCAT("SQL ","IS ","FUN!!!") AS stence;
;
"""


df = pd.read_sql_query(
    mysql_query,
    mydb)


df
# Out:
#           stence
# 0  SQL IS FUN!!!

# %%
import mysql.connector as sql
import pandas as pd

mydb = sql.connect (
    host = "localhost",
    user = "root",
    password = "ZAQs8271911c$",
    auth_plugin='mysql_native_password',
    buffered = True,        
    database = "sql_fr_ai"
)



##daily_amount 
#    date_ymd	        amount_day
# 0	2016-04-05	        74950.0
# 1	2016-04-06	        145550.0
#? add string"date" at the end of date_ymd
#? add string "$" at the first of amount_day
mysql_query ="""
SELECT
        CONCAT(date_ymd,"date") AS new_date,
        CONCAT("$",amount_day) AS new_amount
FROM
        daily_amount;
;
"""


df = pd.read_sql_query(
    mysql_query,
    mydb)


df
# Out:
#            new_date new_amount
# 0    2016-04-05date     $74950
# 1    2016-04-06date    $145550
# 2    2016-04-07date     $95900
# 3    2016-04-08date    $160400
# 4    2016-04-09date    $170550
# ..              ...        ...
# 360  2016-12-12date     $69400
# 361  2016-12-13date     $65400
# 362  2016-12-14date     $56300
# 363  2016-12-15date     $61500
# 364  2016-12-16date     $47650
#
# [365 rows x 2 columns]

# %%
import mysql.connector as sql
import pandas as pd

mydb = sql.connect (
    host = "localhost",
    user = "root",
    password = "ZAQs8271911c$",
    auth_plugin='mysql_native_password',
    buffered = True,        
    database = "sql_fr_ai"
)

# Row	date_ymd	weekday	avetemp	totprecip
# 1           2016-10-28          Fri         12.2            18
# 2           2017-09-22          Fri          21.9           20.5

#? 
#? add string "$" at the first of amount_day
mysql_query ="""
SELECT
        CONCAT (FORMAT( (FLOOR( avetemp / 5 ) * 5) , 2) ,'-', FORMAT( ( (FLOOR( avetemp / 5 ) + 1 ) * 5) , 2)) AS avetemp_kbn
FROM
        weather;
;
"""


df = pd.read_sql_query(
    mysql_query,
    mydb)


df
# Out:
#      avetemp_kbn
# 0    10.00-15.00
# 1    20.00-25.00
# 2    10.00-15.00
# 3    15.00-20.00
# 4    15.00-20.00
# ..           ...
# 726  10.00-15.00
# 727  10.00-15.00
# 728  25.00-30.00
# 729   5.00-10.00
# 730  20.00-25.00
#
# [731 rows x 1 columns]
