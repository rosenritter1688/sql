# %% [markdown]
# https://cloud.google.com/bigquery/docs/reference/standard-sql/query-syntax#unpivot_operator

# %%
from IPython.display import Image
Image("/media/bruceashbee/storage drive1/photo_for_notes/41-00 UNPIVOT SAMPLE 02.png")

# %%
from IPython.display import Image
Image("/media/bruceashbee/storage drive1/photo_for_notes/41-00 UNPIVOT SAMPLE 02-02.png")

# %% [markdown]
# # MULTI-COLUMN UNPIVOT OPERATION

# %%
from IPython.display import  Image
Image("/media/bruceashbee/storage drive1/photo_for_notes/41-02multi-column unpivot operation.png")
