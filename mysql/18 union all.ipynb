# %% [markdown]
# # UNION ALL
# > including those duplicates records
# # UNION
# > excluding those dulicates records

# %% [markdown]
# # union and
# # 上下連接～可以選擇column,distinct,where

# %%
import mysql.connector as sql
import pandas as pd

mydb = sql.connect (
    host = "localhost",
    user = "root",
    password = "ZAQs8271911c$",
    auth_plugin='mysql_native_password',
    buffered = True,          
    database = "sql_fr_ai"
)


#? only execute sql query wo passing data to panda dataframe
# mycoursor = mydb.cursor()
# sql_query = """
# select * 
# from  order_report_1
# """
# mycoursor.execute( sql_query )


#? execute sql query  AND  passing data to panda dataframe
# edit sql query here
sql_query = """
select * 
from  order_report_1
"""

df = pd.read_sql_query(
    sql_query,
    mydb)


df.head()
# Out:
#           order_id    date_ymd taste  amount
# 0  2016-04-05-0083  2016-04-05    T1   800.0
# 1  2016-04-05-0028  2016-04-05    T1   800.0
# 2  2016-04-05-0049  2016-04-05    T1   800.0
# 3  2016-04-05-0035  2016-04-05    T2   850.0
# 4  2016-04-05-0016  2016-04-05    T2   850.0

# %%
sql_query = """
SELECT *
FROM order_report_1
UNION ALL
        SELECT *
        FROM order_report_2;
"""


df = pd.read_sql_query(
    sql_query,
    mydb)


df
# Out:
#                order_id    date_ymd taste  amount
# 0       2016-04-05-0083  2016-04-05    T1   800.0
# 1       2016-04-05-0028  2016-04-05    T1   800.0
# 2       2016-04-05-0049  2016-04-05    T1   800.0
# 3       2016-04-05-0035  2016-04-05    T2   850.0
# 4       2016-04-05-0016  2016-04-05    T2   850.0
# ...                 ...         ...   ...     ...
# 102750  2016-12-16-0039  2016-12-16    T7   850.0
# 102751  2016-12-16-0006  2016-12-16    T7   850.0
# 102752  2016-12-16-0052  2016-12-16    T7   850.0
# 102753  2016-12-16-0022  2016-12-16    T7   850.0
# 102754  2016-12-16-0001  2016-12-16    T7   850.0
#
# [102755 rows x 4 columns]

# %% [markdown]
# # bigquery
# ```
# CREATE table if not exists `data-sci-acad-learn-sql.TW14_N10.order_report` AS
# select *
# from
#   `data-sci-acad-learn-sql.TW14_N10.order_report_1`
# union all
#       SELECT *
#       FROM `data-sci-acad-learn-sql.TW14_N10.order_report_2`
# ```

# %% [markdown]
# ##

# %%
import mysql.connector as sql
import pandas as pd

mydb = sql.connect (
    host = "localhost",
    user = "root",
    password = "ZAQs8271911c$",
    auth_plugin='mysql_native_password',
    buffered = True,          # using this for reading table, panda dont need it
    #multi=True,                 # if wanna use mulitple query
    database = "sql_fr_ai"
)

# auth_plugin is needed, can check by commends 
# SELECT user,authentication_string,plugin,host FROM mysql.user;
# check the columns plugin and user


#? only execute sql query wo passing data to panda dataframe
# mycoursor = mydb.cursor()
# mycoursor.execute(
#     """
#     #! create database
#     create database if not exists database_name;
#     """
# )


#? execute sql query  AND  passing data to panda dataframe
# edit sql query here
sql_query = """
select count(* )
from  order_report
"""
# run sql queries and Importing data from a MySQL database 
# into Pandas data frame

df = pd.read_sql_query(
    sql_query,
    mydb)


df
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/mysql/connector/connection_cext.py:555, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     554         query = query.encode("utf-8")
# --> 555     self._cmysql.query(
#     556         query,
#     557         raw=raw,
#     558         buffered=buffered,
#     559         raw_as_string=raw_as_string,
#     560         query_attrs=self._query_attrs,
#     561     )
#     562 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'sql_fr_ai.order_report' doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/pandas/io/sql.py:1595, in SQLiteDatabase.execute(self, *args, **kwargs)
#    1594 else:
# -> 1595     cur.execute(*args)
#    1596 return cur
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/cursor_cext.py:276, in CMySQLCursor.execute(self, operation, params, multi)
#     275 try:
# --> 276     result = self._cnx.cmd_query(
#     277         stmt,
#     278         raw=self._raw,
#     279         buffered=self._buffered,
#     280         raw_as_string=self._raw_as_string,
#     281     )
#     282 except MySQLInterfaceError as err:
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/connection_cext.py:563, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     562 except MySQLInterfaceError as err:
# --> 563     raise get_mysql_exception(
#     564         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     565     ) from err
#     566 except AttributeError as err:
#
# ProgrammingError: 1146 (42S02): Table 'sql_fr_ai.order_report' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# /media/bruceashbee/新增磁碟區2/mysql/18 union all.ipynb Cell 5 in <cell line: 38>()
#      <a href='vscode-notebook-cell:/media/bruceashbee/%E6%96%B0%E5%A2%9E%E7%A3%81%E7%A2%9F%E5%8D%802/mysql/18%20union%20all.ipynb#W4sZmlsZQ%3D%3D?line=30'>31</a> sql_query = """
#      <a href='vscode-notebook-cell:/media/bruceashbee/%E6%96%B0%E5%A2%9E%E7%A3%81%E7%A2%9F%E5%8D%802/mysql/18%20union%20all.ipynb#W4sZmlsZQ%3D%3D?line=31'>32</a> select count(* )
#      <a href='vscode-notebook-cell:/media/bruceashbee/%E6%96%B0%E5%A2%9E%E7%A3%81%E7%A2%9F%E5%8D%802/mysql/18%20union%20all.ipynb#W4sZmlsZQ%3D%3D?line=32'>33</a> from  order_report
#      <a href='vscode-notebook-cell:/media/bruceashbee/%E6%96%B0%E5%A2%9E%E7%A3%81%E7%A2%9F%E5%8D%802/mysql/18%20union%20all.ipynb#W4sZmlsZQ%3D%3D?line=33'>34</a> """
#      <a href='vscode-notebook-cell:/media/bruceashbee/%E6%96%B0%E5%A2%9E%E7%A3%81%E7%A2%9F%E5%8D%802/mysql/18%20union%20all.ipynb#W4sZmlsZQ%3D%3D?line=34'>35</a> # run sql queries and Importing data from a MySQL database
#      <a href='vscode-notebook-cell:/media/bruceashbee/%E6%96%B0%E5%A2%9E%E7%A3%81%E7%A2%9F%E5%8D%802/mysql/18%20union%20all.ipynb#W4sZmlsZQ%3D%3D?line=35'>36</a> # into Pandas data frame
# ---> <a href='vscode-notebook-cell:/media/bruceashbee/%E6%96%B0%E5%A2%9E%E7%A3%81%E7%A2%9F%E5%8D%802/mysql/18%20union%20all.ipynb#W4sZmlsZQ%3D%3D?line=37'>38</a> df = pd.read_sql_query(
#      <a href='vscode-notebook-cell:/media/bruceashbee/%E6%96%B0%E5%A2%9E%E7%A3%81%E7%A2%9F%E5%8D%802/mysql/18%20union%20all.ipynb#W4sZmlsZQ%3D%3D?line=38'>39</a>     sql_query,
#      <a href='vscode-notebook-cell:/media/bruceashbee/%E6%96%B0%E5%A2%9E%E7%A3%81%E7%A2%9F%E5%8D%802/mysql/18%20union%20all.ipynb#W4sZmlsZQ%3D%3D?line=39'>40</a>     mydb)
#      <a href='vscode-notebook-cell:/media/bruceashbee/%E6%96%B0%E5%A2%9E%E7%A3%81%E7%A2%9F%E5%8D%802/mysql/18%20union%20all.ipynb#W4sZmlsZQ%3D%3D?line=42'>43</a> df
#
# File /usr/lib/python3/dist-packages/pandas/io/sql.py:326, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     272 """Read SQL query into a DataFrame.
#     273
#     274 Returns a DataFrame corresponding to the result set of the query
#    (...)
#     323 parameter will be converted to UTC.
#     324 """
#     325 pandas_sql = pandasSQL_builder(con)
# --> 326 return pandas_sql.read_query(
#     327     sql,
#     328     index_col=index_col,
#     329     params=params,
#     330     coerce_float=coerce_float,
#     331     parse_dates=parse_dates,
#     332     chunksize=chunksize,
#     333 )
#
# File /usr/lib/python3/dist-packages/pandas/io/sql.py:1645, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1634 def read_query(
#    1635     self,
#    1636     sql,
#    (...)
#    1641     chunksize=None,
#    1642 ):
#    1644     args = _convert_params(sql, params)
# -> 1645     cursor = self.execute(*args)
#    1646     columns = [col_desc[0] for col_desc in cursor.description]
#    1648     if chunksize is not None:
#
# File /usr/lib/python3/dist-packages/pandas/io/sql.py:1610, in SQLiteDatabase.execute(self, *args, **kwargs)
#    1605     raise_with_traceback(ex)
#    1607 ex = DatabaseError(
#    1608     "Execution failed on sql '{sql}': {exc}".format(sql=args[0], exc=exc)
#    1609 )
# -> 1610 raise_with_traceback(ex)
#
# File /usr/lib/python3/dist-packages/pandas/compat/__init__.py:47, in raise_with_traceback(exc, traceback)
#      45 if traceback == Ellipsis:
#      46     _, _, traceback = sys.exc_info()
# ---> 47 raise exc.with_traceback(traceback)
#
# File /usr/lib/python3/dist-packages/pandas/io/sql.py:1595, in SQLiteDatabase.execute(self, *args, **kwargs)
#    1593         cur.execute(*args, **kwargs)
#    1594     else:
# -> 1595         cur.execute(*args)
#    1596     return cur
#    1597 except Exception as exc:
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/cursor_cext.py:276, in CMySQLCursor.execute(self, operation, params, multi)
#     271             raise ProgrammingError(
#     272                 "Not all parameters were used in the SQL statement"
#     273             )
#     275 try:
# --> 276     result = self._cnx.cmd_query(
#     277         stmt,
#     278         raw=self._raw,
#     279         buffered=self._buffered,
#     280         raw_as_string=self._raw_as_string,
#     281     )
#     282 except MySQLInterfaceError as err:
#     283     raise get_mysql_exception(
#     284         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     285     ) from err
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/connection_cext.py:563, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     555     self._cmysql.query(
#     556         query,
#     557         raw=raw,
#    (...)
#     560         query_attrs=self._query_attrs,
#     561     )
#     562 except MySQLInterfaceError as err:
# --> 563     raise get_mysql_exception(
#     564         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     565     ) from err
#     566 except AttributeError as err:
#     567     addr = (
#     568         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     569     )
#
# DatabaseError: Execution failed on sql '
# select count(* )
# from  order_report
# ': 1146 (42S02): Table 'sql_fr_ai.order_report' doesn't exist
