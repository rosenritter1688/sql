# %%
import mysql.connector as sql
import pandas as pd

mydb = sql.connect (
    host = "localhost",
    user = "root",
    password = "ZAQs8271911c$",
    auth_plugin='mysql_native_password',
    buffered = True,          # using this for reading table, panda dont need it
    #multi=True,                 # if wanna use mulitple query
    database = "sql_fr_ai"
)

#? only execute sql query wo passing data to panda dataframe
# mycoursor = mydb.cursor()
# sql_query = """
# SELECT
#             *
# FROM  
#             daily_amount
# ORDER BY
#             daily_amount;
# """
# mycoursor.execute(sql_query)


#? execute sql query  AND  passing data to panda dataframe

sql_query = """
SELECT
            *
FROM  
            practice_convert_row_column            
"""
# run sql queries and Importing data from a MySQL database 
# into Pandas data frame

df = pd.read_sql_query(
    sql_query,
    mydb)


df
# Out:
#   Gender  total_ppl  AVG(Computer)  AVG(Reading)  AVG(Movie)  AVG(Music)  \
# 0      M         66         2.5909        2.5758      2.3333      2.1818
#
#    AVG(Game)  AVG(Gamble)  AVG(Sports)  AVG(Travel)  AVG(WatchingSports)  \
# 0     1.8485       1.8485        1.697       1.6364               1.3182
#
#    AVG(Mobility)
# 0          1.303

# %%
from IPython.display import Image
Image("/media/bruceashbee/新增磁碟區1/photo_for_notes/sql_schooling_q2.png")

# %%
from IPython.display import Image
Image("/media/bruceashbee/新增磁碟區1/photo_for_notes/sql_schooling_q2_2.png")

# %% [markdown]
# # info
# ##### https://stackoverflow.com/questions/13944417/mysql-convert-column-to-row-pivot-table

# %%
from IPython.display import  Image
Image("/media/bruceashbee/新增磁碟區1/photo_for_notes/mysql_convert_column_to_row.png")

# %% [markdown]
# ### What you need to do is first, unpivot the data and then pivot it. But unfortunately MySQL does not have these functions so you will need to replicate them using a UNION ALL query for the unpivot and an aggregate function with a CASE for the pivot.
#
# ### The unpivot or UNION ALL piece takes the data from your col1, col2, etc and turns it into multiple rows:
# ```
# select id, month, col1 value, 'col1' desc
# from yourtable
# union all
# select id, month, col2 value, 'col2' desc
# from yourtable
# union all
# select id, month, col3 value, 'col3' desc
# from yourtable
# union all
# select id, month, col4 value, 'col4' desc
# from yourtable
# ```

# %%
# 	Gender	total_ppl	AVG(Computer)	AVG(Reading)	AVG(Movie)	AVG(Music)	AVG(Game)	AVG(Gamble)	AVG(Sports)	AVG(Travel)	AVG(WatchingSports)	AVG(Mobility)
# 0	M	66	2.5909	2.5758	2.3333	2.1818	1.8485	1.8485	1.697	1.6364	1.3182	1.303
sql_query = """
SELECT
            *
FROM  
            practice_convert_row_column            
"""
# run sql queries and Importing data from a MySQL database 
# into Pandas data frame

df = pd.read_sql_query(
    sql_query,
    mydb)


df
# Out:
#   Gender  total_ppl  AVG(Computer)  AVG(Reading)  AVG(Movie)  AVG(Music)  \
# 0      M         66         2.5909        2.5758      2.3333      2.1818
#
#    AVG(Game)  AVG(Gamble)  AVG(Sports)  AVG(Travel)  AVG(WatchingSports)  \
# 0     1.8485       1.8485        1.697       1.6364               1.3182
#
#    AVG(Mobility)
# 0          1.303
