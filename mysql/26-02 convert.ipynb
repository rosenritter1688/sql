# %% [markdown]
# # convert
# # convert ( value , data_type);
# # cast ( value as data_type;
# #### cast() function also the same

# %%
from IPython.display import  Image
Image("/media/bruceashbee/新增磁碟區2/photo_for_notes/data_types.png")

# %%
import mysql.connector as sql
import pandas as pd

mydb = sql.connect (
    host = "localhost",
    user = "root",
    password = "ZAQs8271911c$",
    auth_plugin='mysql_native_password',
    buffered = True,        
    database = "sql_fr_ai"
)

mysql_query ="""
SELECT
            CONVERT(100, CHAR)
;
"""
# #? execute sql query only
# mycoursor = mydb.cursor()
# mycoursor.execute(
#     mysql_query
# )
#? use pandas to read table
df = pd.read_sql_query(
    mysql_query,
    mydb)


df
# Out:
#   CONVERT(100, CHAR)
# 0                100

# %%
import mysql.connector as sql
import pandas as pd

mydb = sql.connect (
    host = "localhost",
    user = "root",
    password = "ZAQs8271911c$",
    auth_plugin='mysql_native_password',
    buffered = True,        
    database = "sql_fr_ai"
)

# date_ymd	            amount_day	weekday	avetemp	totprecip	public_holiday
# 0	2016-04-01	    88850.0	            Fri	            12.8	        2.5	            None
# 1	2016-04-02	    73050.0	            Sat	            10.5	        1.5	                None
# 2	2016-04-03	    91050.0	            Sun	            13.1            4.0	            None


mysql_query ="""
CREATE TABLE  if not exists temp_cal AS
SELECT
            amount_day,
            CONCAT( # combine 3 strings
                         LPAD( (CAST( (FLOOR ( avetemp / 5 ) * 5 ) AS CHAR )) , 2, '0' ) ,  # string 1
                        '-', # string 2
                        LPAD( (CAST( ( ( FLOOR ( avetemp / 5 ) + 1 )* 5 ) AS CHAR )) , 2, '0' ) # string 3
                        ) AS avetemp_5,
            CASE 
                        WHEN weekday = "Sat" OR weekday = "Sun" OR weekday <> Null
                                    THEN 1
                                    ELSE 0
            END  AS  holiday_flag,
            CASE
                        WHEN totprecip > 0
                                    THEN 1
                                    ELSE 0
            END AS rain_flag
        

            

FROM
            datamart;
;
"""
#? execute sql query only
mycoursor = mydb.cursor()
mycoursor.execute(
    mysql_query
)
# #? use pandas to read table
# df = pd.read_sql_query(
#     mysql_query,
#     mydb)


# df
