# %% [markdown]
# # Google Drive をマウントし、データの置き場所を設定しておく

# %%
# 必要なライブラリを読み込む
from google.colab import drive 

# Google ドライブをマウントする
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# データの置き場所（フォルダ名）を設定しておく
myfolder = "drive/My Drive/Learn-Preprocessing/DATA/"

# %% [markdown]
# # 必要なライブラリをインポートする

# %%
import pandas as pd
